# %%
#Number of Migrants = 1

import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_LifeTable/Hybridization/2SLiM_Files/"
#FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_MigV2/"

TSEP = [0,5000,10000,15000,20000,25000,30000]
#TSEP = [20000]
nmig = 1

counter = 0

expected_ratio = 0.75
SR = 0.5
Ne = 4*750*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
expected_teta = round (4*Ne*40*1.25e-8,10)

for tsep in TSEP:
    L_XtoA = []
    N = int(1+(tsep+30000)/500)
    for NUM in range(1,21):

        XtoA = []
        File = FOLDER + f"NWFLT_Hyb_Pi_WMF{tsep},{nmig},{NUM}.txt"
        if os.path.isfile(File):
            with open(File, 'r', encoding='utf-8') as Text:
                for ligne in Text:
                    Values = ligne.strip().split()
                    if len(Values) > 1:
                        try:
                            XtoA.append(float(Values[1]) / float(Values[0]))
                        except (ValueError, ZeroDivisionError):
                            pass  # ou afficher un message d'erreur si tu veux
        L_XtoA .append(XtoA)
    
    XtoA_mean = [0 for j in range (N)]
    for j in range (N):
        S = 0
        for el in L_XtoA: 
                S += el[j]
        XtoA_mean[j] = S/len(L_XtoA)
    Steps = [500*j for j in range (N)]
    
    print("------------------------------------------------------------------------------------------------------------")
    print("Separation Time = "+str(tsep))
    print("Number of Migrant: "+str(nmig))
    print()

    fig, ax = mp.subplots(figsize=(10, 5))
    fig.suptitle(f"X-to-A Ratio: WMF Seperation Time = {tsep}  Number of Migrant = {nmig} ", fontsize=14)

    ax.plot(Steps, XtoA_mean)
    ax.set_xlabel("Years after Seperation")
    ax.set_ylabel("X-to-A Ratio = PiX / PiA")
    ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
    ax.axvline(x=tsep, color='red', linestyle='--', linewidth=1, label='Hybridization')
    ax.legend()

    mp.show()
# Out:
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 0
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 5000
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 10000
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 15000
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 20000
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 25000
# Number of Migrant: 1
# ------------------------------------------------------------------------------------------------------------
# Separation Time = 30000
# Number of Migrant: 1

# %%
#Number of Migrants = 10

import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_LifeTable/Hybridization/"
#FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_MigV2/"

TSEP = [0,5000,10000,15000,20000,25000,30000]
#TSEP = [20000]
nmig = 10

counter = 0

expected_ratio = 0.75
SR = 0.5
Ne = 4*750*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
expected_teta = round (4*Ne*40*1.25e-8,10)

for tsep in TSEP:
    L_XtoA = []
    N = int(1+(tsep+30000)/500)
    for NUM in range(1,21):

        XtoA = []
        File = FOLDER + f"NWFLT_Hyb_Pi_WMF{tsep},{nmig},{NUM}.txt"
        if os.path.isfile(File):
            with open(File, 'r', encoding='utf-8') as Text:
                for ligne in Text:
                    Values = ligne.strip().split()
                    if len(Values) > 1:
                        try:
                            XtoA.append(float(Values[1]) / float(Values[0]))
                        except (ValueError, ZeroDivisionError):
                            pass  # ou afficher un message d'erreur si tu veux
        L_XtoA .append(XtoA)
    
    XtoA_mean = [0 for j in range (N)]
    for j in range (N):
        S = 0
        for el in L_XtoA: 
                S += el[j]
        XtoA_mean[j] = S/len(L_XtoA)
    Steps = [500*j for j in range (N)]
    
    print("------------------------------------------------------------------------------------------------------------")
    print("Separation Time = "+str(tsep))
    print("Number of Migrant: "+str(nmig))
    print()

    fig, ax = mp.subplots(figsize=(10, 5))
    fig.suptitle(f"X-to-A Ratio: WMF Seperation Time = {tsep}  Number of Migrant = {nmig} ", fontsize=14)

    ax.plot(Steps, XtoA_mean)
    ax.set_xlabel("Years after Seperation")
    ax.set_ylabel("X-to-A Ratio = PiX / PiA")
    ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
    ax.axvline(x=tsep, color='red', linestyle='--', linewidth=1, label='Hybridization')
    ax.legend()

    mp.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 43
#      41     S = 0
#      42     for el in L_XtoA:
# ---> 43             S += el[j]
#      44     XtoA_mean[j] = S/len(L_XtoA)
#      45 Steps = [500*j for j in range (N)]
#
# IndexError: list index out of range

# %%
#Number of Migrants = 50

import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_LifeTable/Hybridization/"
#FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_MigV2/"

TSEP = [0,5000,10000,15000,20000,25000,30000]
#TSEP = [20000]
nmig = 50

counter = 0

expected_ratio = 0.75
SR = 0.5
Ne = 4*750*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
expected_teta = round (4*Ne*40*1.25e-8,10)

for tsep in TSEP:
    L_XtoA = []
    N = int(1+(tsep+30000)/500)
    for NUM in range(1,21):

        XtoA = []
        File = FOLDER + f"NWFLT_Hyb_Pi_WMF{tsep},{nmig},{NUM}.txt"
        if os.path.isfile(File):
            with open(File, 'r', encoding='utf-8') as Text:
                for ligne in Text:
                    Values = ligne.strip().split()
                    if len(Values) > 1:
                        try:
                            XtoA.append(float(Values[1]) / float(Values[0]))
                        except (ValueError, ZeroDivisionError):
                            pass  # ou afficher un message d'erreur si tu veux
        L_XtoA .append(XtoA)
    
    XtoA_mean = [0 for j in range (N)]
    for j in range (N):
        S = 0
        for el in L_XtoA: 
                S += el[j]
        XtoA_mean[j] = S/len(L_XtoA)
    Steps = [500*j for j in range (N)]
    
    print("------------------------------------------------------------------------------------------------------------")
    print("Separation Time = "+str(tsep))
    print("Number of Migrant: "+str(nmig))
    print()

    fig, ax = mp.subplots(figsize=(10, 5))
    fig.suptitle(f"X-to-A Ratio: WMF Seperation Time = {tsep}  Number of Migrant = {nmig} ", fontsize=14)

    ax.plot(Steps, XtoA_mean)
    ax.set_xlabel("Years after Seperation")
    ax.set_ylabel("X-to-A Ratio = PiX / PiA")
    ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
    ax.axvline(x=tsep, color='red', linestyle='--', linewidth=1, label='Hybridization')
    ax.legend()

    mp.show()

# %%
#Number of Migrants = 100

import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_LifeTable/Hybridization/"
#FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_MigV2/"

TSEP = [0,5000,10000,15000,20000,25000,30000]
#TSEP = [20000]
nmig = 100

counter = 0

expected_ratio = 0.75
SR = 0.5
Ne = 4*750*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
expected_teta = round (4*Ne*40*1.25e-8,10)

for tsep in TSEP:
    L_XtoA = []
    N = int(1+(tsep+30000)/500)
    for NUM in range(1,21):

        XtoA = []
        File = FOLDER + f"NWFLT_Hyb_Pi_WMF{tsep},{nmig},{NUM}.txt"
        if os.path.isfile(File):
            with open(File, 'r', encoding='utf-8') as Text:
                for ligne in Text:
                    Values = ligne.strip().split()
                    if len(Values) > 1:
                        try:
                            XtoA.append(float(Values[1]) / float(Values[0]))
                        except (ValueError, ZeroDivisionError):
                            pass  # ou afficher un message d'erreur si tu veux
        L_XtoA .append(XtoA)
    
    XtoA_mean = [0 for j in range (N)]
    for j in range (N):
        S = 0
        for el in L_XtoA: 
                S += el[j]
        XtoA_mean[j] = S/len(L_XtoA)
    Steps = [500*j for j in range (N)]
    
    print("------------------------------------------------------------------------------------------------------------")
    print("Separation Time = "+str(tsep))
    print("Number of Migrant: "+str(nmig))
    print()

    fig, ax = mp.subplots(figsize=(10, 5))
    fig.suptitle(f"X-to-A Ratio: WMF Seperation Time = {tsep}  Number of Migrant = {nmig} ", fontsize=14)

    ax.plot(Steps, XtoA_mean)
    ax.set_xlabel("Years after Seperation")
    ax.set_ylabel("X-to-A Ratio = PiX / PiA")
    ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
    ax.axvline(x=tsep, color='red', linestyle='--', linewidth=1, label='Hybridization')
    ax.legend()

    mp.show()

# %%
#Number of Migrants = 300

import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_LifeTable/Hybridization/"
#FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_MigV2/"

TSEP = [0,5000,10000,15000,20000,25000,30000]
#TSEP = [20000]
nmig = 300

counter = 0

expected_ratio = 0.75
SR = 0.5
Ne = 4*750*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
expected_teta = round (4*Ne*40*1.25e-8,10)

for tsep in TSEP:
    L_XtoA = []
    N = int(1+(tsep+30000)/500)
    for NUM in range(1,21):

        XtoA = []
        File = FOLDER + f"NWFLT_Hyb_Pi_WMF{tsep},{nmig},{NUM}.txt"
        if os.path.isfile(File):
            with open(File, 'r', encoding='utf-8') as Text:
                for ligne in Text:
                    Values = ligne.strip().split()
                    if len(Values) > 1:
                        try:
                            XtoA.append(float(Values[1]) / float(Values[0]))
                        except (ValueError, ZeroDivisionError):
                            pass  # ou afficher un message d'erreur si tu veux
        L_XtoA .append(XtoA)
    
    XtoA_mean = [0 for j in range (N)]
    for j in range (N):
        S = 0
        for el in L_XtoA: 
                S += el[j]
        XtoA_mean[j] = S/len(L_XtoA)
    Steps = [500*j for j in range (N)]
    
    print("------------------------------------------------------------------------------------------------------------")
    print("Separation Time = "+str(tsep))
    print("Number of Migrant: "+str(nmig))
    print()

    fig, ax = mp.subplots(figsize=(10, 5))
    fig.suptitle(f"X-to-A Ratio: WMF Seperation Time = {tsep}  Number of Migrant = {nmig} ", fontsize=14)

    ax.plot(Steps, XtoA_mean)
    ax.set_xlabel("Years after Seperation")
    ax.set_ylabel("X-to-A Ratio = PiX / PiA")
    ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
    ax.axvline(x=tsep, color='red', linestyle='--', linewidth=1, label='Hybridization')
    ax.legend()

    mp.show()
