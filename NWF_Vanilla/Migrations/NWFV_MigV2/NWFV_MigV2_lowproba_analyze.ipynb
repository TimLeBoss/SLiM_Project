# %%
# Wright Fisher model
import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFV_MigV2/"

Prob_Mig = [k/200 for k in range(1,20)]
LRatio_star = [0 for k in range (len(Prob_Mig))]
LRatio_circle = [0 for k in range (len(Prob_Mig))]
counter = 0

expected_ratio = 0.75
#Ne = 4*500*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
#expected_teta = round (4*Ne*1.25e-8,10)
n = 10
NeA = 50
NeX = 3/4 * NeA
mu = 1.25e-8
Pi_SA = 4*n*NeA*mu
Pi_SX = 4*n*NeX*mu
L_PiTX_PiTA = []

for pmig in Prob_Mig:
    mA = 0 + 1/2 * (pmig+0)
    mX = 0 + 1/3 * (pmig+2*0)
    Pi_TA = Pi_SA*(1+((n-1)**2)/(4*mA*NeA*n**2))
    Pi_TX = Pi_SX*(1+((n-1)**2)/(4*mX*NeX*n**2))
    PiTX_PiTA = Pi_TX / Pi_TA
    L_PiTX_PiTA.append(PiTX_PiTA)
    
    Star = []
    Circle = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_star_Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Star.append(float(Values[1])/float(Values[0]))
            Text.close()
            
        File = FOLDER+"NWFV_circle_Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Circle.append(float(Values[1])/float(Values[0]))
            Text.close()
    
    LRatio_star[counter] = Star
    LRatio_circle[counter] = Circle
    counter += 1
    Star_median = np.median(Star)
    Circle_median = np.median(Circle)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration Probability = "+str(pmig))
    print("Expected Ratio: ",expected_ratio)
    print("Expected Ratio with Subpopulations: ",round (PiTX_PiTA,3))
    print()
    print("Number of star simulations: ",len(Star))
    print("Median Ratio: ",Star_median)
    print()
    print("Number of Circle simulations: ",len(Circle))
    print("Median Ratio: ",Circle_median)

print("------------------------------------------------------------------------------------------------------------")
print("Star Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Star Migration", fontsize=14)

ax.boxplot(LRatio_star,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio wSubPop')
ax.legend()

#fig.savefig(FOLDER_output+'WF_NWF_SexRatio'+str(SR)+'.png') 
mp.show()


print("------------------------------------------------------------------------------------------------------------")
print("Circle Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Circle Migration", fontsize=14)

ax.boxplot(LRatio_circle,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio wSubPop')
ax.legend() 

#fig.savefig(FOLDER_output+'WF_NWF_SexRatio'+str(SR)+'.png') 
mp.show()
# Out:
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.005
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  1.214
#
# Number of star simulations:  500
# Median Ratio:  1.0465898465215726
#
# Number of Circle simulations:  500
# Median Ratio:  1.0866800290451288
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.01
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  1.086
#
# Number of star simulations:  500
# Median Ratio:  0.9548414726088548
#
# Number of Circle simulations:  500
# Median Ratio:  1.0379872391326672
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.015
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  1.013
#
# Number of star simulations:  500
# Median Ratio:  0.9042404713595209
#
# Number of Circle simulations:  500
# Median Ratio:  0.992738371729106
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.02
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.966
#
# Number of star simulations:  500
# Median Ratio:  0.8765975232725407
#
# Number of Circle simulations:  500
# Median Ratio:  0.9580265415977869
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.025
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.934
#
# Number of star simulations:  500
# Median Ratio:  0.8562388664125069
#
# Number of Circle simulations:  500
# Median Ratio:  0.9285617801741519
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.03
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.909
#
# Number of star simulations:  500
# Median Ratio:  0.8396043523042152
#
# Number of Circle simulations:  500
# Median Ratio:  0.9079091472099872
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.035
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.891
#
# Number of star simulations:  500
# Median Ratio:  0.8307808382133088
#
# Number of Circle simulations:  500
# Median Ratio:  0.8958220566335592
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.04
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.876
#
# Number of star simulations:  500
# Median Ratio:  0.8251313454714762
#
# Number of Circle simulations:  500
# Median Ratio:  0.8764825651441716
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.045
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.864
#
# Number of star simulations:  500
# Median Ratio:  0.817669915181959
#
# Number of Circle simulations:  500
# Median Ratio:  0.8626647354227308
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.05
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.855
#
# Number of star simulations:  500
# Median Ratio:  0.8154279091317247
#
# Number of Circle simulations:  500
# Median Ratio:  0.8518886905541472
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.055
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.846
#
# Number of star simulations:  500
# Median Ratio:  0.8054169219819053
#
# Number of Circle simulations:  500
# Median Ratio:  0.850375601539411
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.06
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.839
#
# Number of star simulations:  500
# Median Ratio:  0.8067949620622941
#
# Number of Circle simulations:  500
# Median Ratio:  0.8422024822708014
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.065
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.833
#
# Number of star simulations:  500
# Median Ratio:  0.7959026779354825
#
# Number of Circle simulations:  500
# Median Ratio:  0.844178661975254
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.07
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.828
#
# Number of star simulations:  500
# Median Ratio:  0.795090356775118
#
# Number of Circle simulations:  500
# Median Ratio:  0.8366025280268686
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.075
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.823
#
# Number of star simulations:  500
# Median Ratio:  0.792805097030275
#
# Number of Circle simulations:  500
# Median Ratio:  0.8274360356432378
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.08
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.819
#
# Number of star simulations:  500
# Median Ratio:  0.7936911504065159
#
# Number of Circle simulations:  500
# Median Ratio:  0.8234409609623353
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.085
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.815
#
# Number of star simulations:  500
# Median Ratio:  0.792630577751563
#
# Number of Circle simulations:  500
# Median Ratio:  0.8149707104835346
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.09
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.812
#
# Number of star simulations:  500
# Median Ratio:  0.787145335634494
#
# Number of Circle simulations:  500
# Median Ratio:  0.8203222668386164
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.095
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.809
#
# Number of star simulations:  500
# Median Ratio:  0.7855963840570706
#
# Number of Circle simulations:  500
# Median Ratio:  0.8157424029944663
# ------------------------------------------------------------------------------------------------------------
# Star Migration
# ------------------------------------------------------------------------------------------------------------
# Circle Migration
