# %%
# Pi on whole population
import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_Vanilla/Migrations/NWFV_1MigV2/"
FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_1MigV2/"

Prob_Mig = [k/20 for k in range(1,20)]+[1.0]
LRatio_star = [0 for k in range (len(Prob_Mig))]
LRatio_circle = [0 for k in range (len(Prob_Mig))]
counter = 0

expected_ratio = 0.75
#Ne = 4*500*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
#expected_teta = round (4*Ne*1.25e-8,10)
n = 15
NeA = 50
NeX = 3/4 * NeA
mu = 40 * 1.25e-8
Pi_SA = 4*n*NeA*mu
Pi_SX = 4*n*NeX*mu
L_PiTX_PiTA = []

for pmig in Prob_Mig:
    mA = 0 + 1/2 * (pmig+0)
    mX = 0 + 1/3 * (pmig+2*0)
    Pi_TA = Pi_SA*(1+((n-1)**2)/(4*mA*NeA*n**2))
    Pi_TX = Pi_SX*(1+((n-1)**2)/(4*mX*NeX*n**2))
    PiTX_PiTA = Pi_TX / Pi_TA
    L_PiTX_PiTA.append(PiTX_PiTA)
    
    Star = []
    Circle = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_star_1Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Star.append(float(Values[1])/float(Values[0]))
            Text.close()
            
        File = FOLDER+"NWFV_circle_1Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Circle.append(float(Values[1])/float(Values[0]))
            Text.close()
    
    LRatio_star[counter] = Star
    LRatio_circle[counter] = Circle
    counter += 1
    Star_median = np.median(Star)
    Circle_median = np.median(Circle)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration Probability = "+str(pmig))
    print("Expected Ratio: ",expected_ratio)
    print("Expected Ratio with Subpopulations: ",round (PiTX_PiTA,3))
    print()
    print("Number of star simulations: ",len(Star))
    print("Median Ratio: ",Star_median)
    print()
    print("Number of Circle simulations: ",len(Circle))
    print("Median Ratio: ",Circle_median)

print("------------------------------------------------------------------------------------------------------------")
print("Star Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Star Migration: 1 Migration | whole population", fontsize=14)

ax.boxplot(LRatio_star,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio θ')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio πTG')
ax.legend()

#fig.savefig(FOLDER_output+'NWFV_MigV2_star.png') 
mp.show()


print("------------------------------------------------------------------------------------------------------------")
print("Circle Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Circle Migration: 1 Migration | whole population", fontsize=14)

ax.boxplot(LRatio_circle,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio θ')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio πTG')
ax.legend() 

#fig.savefig(FOLDER_output+'NWFV_MigV2_circle.png') 
mp.show()
# Out:
# /home/timothe_dandoy/.conda/envs/SLiM_Project/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/timothe_dandoy/.conda/envs/SLiM_Project/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.05
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.861
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  96
# Median Ratio:  0.8981795032333937
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.1
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.81
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  98
# Median Ratio:  0.83850626393142
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.15
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.791
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  98
# Median Ratio:  0.8164053347331433
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.2
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.781
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.8038081919193727
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.25
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.775
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7956229825121821
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.3
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.771
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7929576221255124
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.35
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.768
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.787880321325219
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.4
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.766
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.786029086403293
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.45
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.764
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7840290855619235
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.5
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.763
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7823367234734229
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.55
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.762
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7807392379570317
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.6
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.761
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7806169787512881
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.65
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.76
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  99
# Median Ratio:  0.7799069809858191
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.7
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.759
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  71
# Median Ratio:  0.7793360285547787
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.75
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.759
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  37
# Median Ratio:  0.7756476116611158
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.8
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.758
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  80
# Median Ratio:  0.7789639483108983
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.85
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.758
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  92
# Median Ratio:  0.776945693307086
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.9
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.757
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  99
# Median Ratio:  0.775895975597394
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.95
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.757
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  86
# Median Ratio:  0.7753780775249269
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 1.0
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.756
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7749616217535429
# ------------------------------------------------------------------------------------------------------------
# Star Migration
# ------------------------------------------------------------------------------------------------------------
# Circle Migration

# %%
# Pi on whole population
import matplotlib.pyplot as mp
import numpy as np
import os 

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWF_Vanilla/Migrations/NWFV_1MigV2/"
FOLDER_output = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/done/NWFV_1MigV2/"

Prob_Mig = [k/20 for k in range(1,20)]+[1.0]
LRatio_star = [0 for k in range (len(Prob_Mig))]
LRatio_circle = [0 for k in range (len(Prob_Mig))]
counter = 0
id_pop = 0 # 0 to 14

expected_ratio = 0.75
#Ne = 4*500*(1-SR)*SR   # Ne = 4*Nm*Nf/N  => Ne = 4*N*(1-SR)*SR 
#expected_teta = round (4*Ne*1.25e-8,10)
n = 15
NeA = 50
NeX = 3/4 * NeA
mu = 40 * 1.25e-8
Pi_SA = 4*n*NeA*mu
Pi_SX = 4*n*NeX*mu
L_PiTX_PiTA = []

for pmig in Prob_Mig:
    mA = 0 + 1/2 * (pmig+0)
    mX = 0 + 1/3 * (pmig+2*0)
    Pi_TA = Pi_SA*(1+((n-1)**2)/(4*mA*NeA*n**2))
    Pi_TX = Pi_SX*(1+((n-1)**2)/(4*mX*NeX*n**2))
    PiTX_PiTA = Pi_TX / Pi_TA
    L_PiTX_PiTA.append(PiTX_PiTA)
    
    Star = []
    Circle = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_star_1Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Star.append(float(Values[(id_pop+1)*3+1])/float(Values[(id_pop+1)*3+0]))
            Text.close()
            
        File = FOLDER+"NWFV_circle_1Mig"+str(pmig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Circle.append(float(Values[(id_pop+1)*3+1])/float(Values[(id_pop+1)*3+0]))
            Text.close()
    
    LRatio_star[counter] = Star
    LRatio_circle[counter] = Circle
    counter += 1
    Star_median = np.median(Star)
    Circle_median = np.median(Circle)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration Probability = "+str(pmig))
    print("Expected Ratio: ",expected_ratio)
    print("Expected Ratio with Subpopulations: ",round (PiTX_PiTA,3))
    print()
    print("Number of star simulations: ",len(Star))
    print("Median Ratio: ",Star_median)
    print()
    print("Number of Circle simulations: ",len(Circle))
    print("Median Ratio: ",Circle_median)

print("------------------------------------------------------------------------------------------------------------")
print("Star Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Star Migration: 1 Migration | one population", fontsize=14)

ax.boxplot(LRatio_star,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio θ')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio πTG')
ax.legend()

#fig.savefig(FOLDER_output+'NWFV_MigV2_star.png') 
mp.show()


print("------------------------------------------------------------------------------------------------------------")
print("Circle Migration")
print()

fig, ax = mp.subplots(figsize=(10, 5))
fig.suptitle("X-to-A ratio with Circle Migration: 1 Migration | one population", fontsize=14)

ax.boxplot(LRatio_circle,tick_labels=Prob_Mig)
ax.set_xlabel("Males Migration Probability")
ax.set_ylabel("X-to-A Ratio = PiX / PiA")
ax.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio θ')
ax.plot([k for k in range (1,len(Prob_Mig)+1)], L_PiTX_PiTA, marker='D',linestyle='None', color='red', markersize=5, label='Expected Ratio πTG')
ax.legend() 

#fig.savefig(FOLDER_output+'NWFV_MigV2_circle.png') 
mp.show()
# Out:
# /home/timothe_dandoy/.conda/envs/SLiM_Project/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/timothe_dandoy/.conda/envs/SLiM_Project/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.05
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.861
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  96
# Median Ratio:  0.7579559371211739
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.1
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.81
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  98
# Median Ratio:  0.7617331439564142
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.15
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.791
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  98
# Median Ratio:  0.7558440986384876
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.2
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.781
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7554139358778325
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.25
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.775
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7515571444888253
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.3
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.771
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7541189871334633
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.35
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.768
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7516802802629927
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.4
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.766
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7532719417355135
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.45
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.764
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7550398405264012
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.5
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.763
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7543440300515702
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.55
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.762
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7522715565502461
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.6
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.761
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7540665702384921
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.65
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.76
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  99
# Median Ratio:  0.7528758314642435
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.7
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.759
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  71
# Median Ratio:  0.7551276141377461
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.75
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.759
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  37
# Median Ratio:  0.7523324517472286
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.8
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.758
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  80
# Median Ratio:  0.755545125448999
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.85
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.758
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  92
# Median Ratio:  0.7538223329941158
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.9
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.757
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  99
# Median Ratio:  0.753249080359513
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 0.95
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.757
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  86
# Median Ratio:  0.7532846252072315
# ------------------------------------------------------------------------------------------------------------
# Migration Probability = 1.0
# Expected Ratio:  0.75
# Expected Ratio with Subpopulations:  0.756
#
# Number of star simulations:  0
# Median Ratio:  nan
#
# Number of Circle simulations:  100
# Median Ratio:  0.7532095474572484
# ------------------------------------------------------------------------------------------------------------
# Star Migration
# ------------------------------------------------------------------------------------------------------------
# Circle Migration
