# %%
# Star Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Star Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFV_Mig_Onlyfemale/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_Ofemale_star_Mig"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_xlabel("Females Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Females Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Star Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.999103477067283
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.887544679999999e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.7451846290435087
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.85154668e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.7439058493639354
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.79420682e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7470057623414549
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7801522600000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7457700733368218
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7717072e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7483059931380793
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76953512e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7499802160334266
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76367706e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7486938092393725
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76267248e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7476395392884416
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7602515e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7486464790311718
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76445894e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.7465766121484048
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7664614799999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7484654479045288
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7595443400000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7534037829549736
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75404436e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7488833981006147
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.757932e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7473587303365308
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76114332e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.7468095197058175
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75993776e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.749883371239594
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75529146e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.7491434236078595
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7566200599999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7497851961654578
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7607914999999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7493877861314125
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.768099e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.7467224870338729
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76477208e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.062476763195014356    b = 0.7912695998457246
# Regression without proba=0 : a = 0.003154987506530128    b = 0.746421236866336

# %%
# Circle Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Circle Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFV_Mig_Onlyfemale/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_Ofemale_star_Mig"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_xlabel("Females Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Females Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Circle Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.999103477067283
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.887544679999999e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.7451846290435087
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.85154668e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.7439058493639354
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.79420682e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7470057623414549
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7801522600000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7457700733368218
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7717072e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7483059931380793
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76953512e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7499802160334266
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76367706e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7486938092393725
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76267248e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7476395392884416
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7602515e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7486464790311718
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76445894e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.7465766121484048
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7664614799999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7484654479045288
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7595443400000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7534037829549736
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75404436e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7488833981006147
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.757932e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7473587303365308
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76114332e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.7468095197058175
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75993776e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.749883371239594
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75529146e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.7491434236078595
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7566200599999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7497851961654578
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7607914999999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7493877861314125
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.768099e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.7467224870338729
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76477208e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.062476763195014356    b = 0.7912695998457246
# Regression without proba=0 : a = 0.003154987506530128    b = 0.746421236866336
