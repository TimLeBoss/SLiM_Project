# %%
# Star Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Star Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFV_Mig_WFemales/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_WFemale_star_Migration"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_xlabel("Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Star Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.9988813768478871
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.88668734e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.7648281158292777
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.78625028e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.758356734626839
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7592838200000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7601895392414078
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75003536e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7587391739303417
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74682346e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7579890418384265
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7451479200000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7535346131435678
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74398262e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7540060130930895
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74847742e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7553703406951269
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74468054e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7591028069392143
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7433652e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.7562862399491569
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7448243199999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7584081103117194
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7428168199999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7586981112938558
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7410580799999997e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7603944893906828
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7438594600000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7574408852635128
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7391956200000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.7572395454374404
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74444122e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.7569934277747283
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74625972e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.7556035749461847
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75014868e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7616980813983372
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74423534e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7586481053766767
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74392842e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.7541699985709002
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7441865799999997e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.06445650518789393    b = 0.8015891252557747
# Regression without proba=0 : a = -0.0021536888956487452    b = 0.7590155341227403

# %%
# Circle Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Circle Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFV_Mig_WFemales/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_WFemale_circle_Migration"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_xlabel("Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Circle Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.9991820957167677
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.88440568e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.771531925517483
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.84678884e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.7601441587858166
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.79003948e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7554425575603594
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77113766e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7580968993016819
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.763413e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7592391577116993
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7532924999999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7602052773156662
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7499532e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7599335850173372
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7513017e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7562289891361182
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75114084e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7611850182984994
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7453383199999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.759257137999757
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7445111e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7605111239873614
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7483138200000006e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7563961881183925
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74615638e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7604796202088345
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7448648400000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7566271813814578
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.74663844e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.7580674479020587
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7480972400000004e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.7570708193995636
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7460555599999997e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.754821630479092
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7495957600000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7586017611571179
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7446105400000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7569720552568893
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7451655399999998e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.9740069774494751
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  4.266435960000001e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.01102609061263818    b = 0.7861797885301971
# Regression without proba=0 : a = 0.05623779586733151    b = 0.7402161327688843
