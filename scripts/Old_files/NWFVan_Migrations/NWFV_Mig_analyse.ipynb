# %%
# Star Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Star Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFVan_Migrations/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_star_ProbMig"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_title("Star_Migration")
ax1.set_xlabel("Males Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Males Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Star Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.999175514605525
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.88491896e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.8092594902080295
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.8531855800000004e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.7851563532852648
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7963442599999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7793524130840301
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7776537600000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7743849768171176
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77280966e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7749909084699202
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76791096e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7646671157381044
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76703652e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7677766962620363
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75472734e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7671483863348911
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7584801e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7660118134438194
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7577978999999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.7588864376251416
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7600092e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7613555173602771
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7573132800000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7659995664738157
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7608018600000004e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7586994097430445
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76007074e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7628993586331896
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75741156e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.762757573540375
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7567486400000002e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.7556818849865614
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7631214200000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.7575550643416397
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7640388e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7632124104708335
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7585031e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7601832999987534
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.75895274e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.7598004692027598
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76505102e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.08774574542952492    b = 0.8226802375064354
# Regression without proba=0 : a = -0.03201039476665434    b = 0.7845944145534739

# %%
# Circle Migration
import matplotlib.pyplot as mp
import numpy as np
import os 

print("Circle Migration")
print()

FOLDER = "/mnt/primevo/work/timothe_dandoy/SLiM_Project/tmp/NWFVan_Migrations/"
expected_ratio = 0.75
expected_teta = round(4*500*1.25e-8,8)
LPro = [0.0]+[k/20 for k in range(1,20)]+[1.0]

Pi = [0 for k in range(21)]
Pi_M = []
compteur = 0
PIA = [0 for k in range(21)]
for ProbMig in LPro:
    Pi_ratio = []
    PiA = []
    for NUM in range(1,501):
        File = FOLDER+"NWFV_circle_ProbMig"+str(ProbMig)+","+str(NUM)+".txt"
        if os.path.isfile(File):
            Text = open(File, 'r')
            Values = Text.read().split()
            if len(Values) > 0:
                Pi_ratio.append(float(Values[1])/float(Values[0]))
                PiA.append(float(Values[0]))
            Text.close()
    Pi[compteur] = Pi_ratio       
    PIA [compteur] = PiA
    Pi_median = np.median(Pi_ratio)
    Pi_M.append(Pi_median)
    PiA_mean = np.mean(PiA)
    print("------------------------------------------------------------------------------------------------------------")
    print("Migration probability = "+str(ProbMig))
    print("Number of simulations: ",len(Pi_ratio))
    print("Pi median Ratio: ",Pi_median)
    print("Panmictic Teta = 4*Ne*mu = ", expected_teta)
    print("Mean Pi Autosome: ",PiA_mean)
    compteur += 1

Values = [Pi[k] for k in range(21)]  
Labels = [str(k/20) for k in range(21)]

LPro = np.array(LPro)
# Regression with the proba of migration = 0
a_w0, b_w0 = np.polyfit(LPro, Pi_M, 1)
Reg_w0 = a_w0 * LPro + b_w0
# Regression without the 0
a_nw0, b_nw0 = np.polyfit(LPro[1:22],Pi_M[1:22], 1)
Reg_nw0 = a_nw0 * LPro[1:22] + b_nw0

a_nw0_h, b_nw0_h = np.polyfit(LPro[1:12],Pi_M[1:12], 1)
Reg_nw0_h = a_nw0_h * LPro[1:22] + b_nw0_h

print("------------------------------------------------------------------------------------------------------------")
fig1, ax1 = mp.subplots(figsize=(10, 5))
ax1.boxplot(Values,tick_labels=Labels)
ax1.set_title("Circle_Migration")
ax1.set_xlabel("Males Migration Probability")
ax1.set_ylabel("X-to-A Ratio = PiX / PiA")
ax1.axhline(y=expected_ratio, color='green', linestyle='--',linewidth=1, label='Expected Ratio')
ax1.legend()
mp.show()

print("------------------------------------------------------------------------------------------------------------")
print("Regression with proba=0 : a = "+str(a_w0)+"    b = "+str(b_w0) )
print("Regression without proba=0 : a = "+str(a_nw0)+"    b = "+str(b_nw0) )

fig2, ax2 = mp.subplots(figsize=(10, 5))
ax2.plot(LPro,Pi_M,"x",color='black',markersize=6,label="Median X-to-A ratio") 
ax2.plot(LPro,Reg_w0,color = "g",label="Regression with probability of migration = 0\na = "+str(round(a_w0,4))+"    b = "+str(round(b_w0,4))) 
ax2.plot(LPro[1:22],Reg_nw0,color = "r",label="Regression without probability of migration = 0\na = "+str(round(a_nw0,4))+"    b = "+str(round(b_nw0,4)))
#ax2.plot(LPro[1:22],Reg_nw0_h,color = "purple",label="Regression between 0.1 and 0.5 probability of migration\na = "+str(round(a_nw0_h,4))+"    b = "+str(round(b_nw0_h,4)))
#ax2.set_ylim([0.8, 1])
ax2.set_xlabel("Males Migration Probability")
ax2.set_ylabel("X-to-A Ratio = PiX / PiA")
ax2.legend()
mp.show()
# Out:
# Circle Migration
#
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.0
# Number of simulations:  500
# Pi median Ratio:  0.9996965762456489
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  6.88252578e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.05
# Number of simulations:  500
# Pi median Ratio:  0.8601677633242935
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.96609098e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.1
# Number of simulations:  500
# Pi median Ratio:  0.8118105819877777
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.85301162e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.15
# Number of simulations:  500
# Pi median Ratio:  0.7957446523529332
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.8208434200000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.2
# Number of simulations:  500
# Pi median Ratio:  0.7849554941744641
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7992755e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.25
# Number of simulations:  500
# Pi median Ratio:  0.7817779736825576
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7930065e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.3
# Number of simulations:  500
# Pi median Ratio:  0.7743764733871759
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7832650399999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.35
# Number of simulations:  500
# Pi median Ratio:  0.7773518568847011
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77905478e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.4
# Number of simulations:  500
# Pi median Ratio:  0.7710045047740786
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77480982e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.45
# Number of simulations:  500
# Pi median Ratio:  0.7690946465413704
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77136562e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.5
# Number of simulations:  500
# Pi median Ratio:  0.7699156575479954
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76958782e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.55
# Number of simulations:  500
# Pi median Ratio:  0.7635448919411334
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7722254e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.6
# Number of simulations:  500
# Pi median Ratio:  0.7638987779750506
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77015636e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.65
# Number of simulations:  500
# Pi median Ratio:  0.7655396644914279
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.76755226e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.7
# Number of simulations:  500
# Pi median Ratio:  0.7610013120627634
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7663456200000004e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.75
# Number of simulations:  500
# Pi median Ratio:  0.7718229577248503
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7641209999999997e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.8
# Number of simulations:  500
# Pi median Ratio:  0.7590009279488927
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77227476e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.85
# Number of simulations:  500
# Pi median Ratio:  0.7671029628966862
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7633020399999996e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.9
# Number of simulations:  500
# Pi median Ratio:  0.7654712918658058
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7662063800000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 0.95
# Number of simulations:  500
# Pi median Ratio:  0.7605159112599962
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.7712768400000003e-05
# ------------------------------------------------------------------------------------------------------------
# Migration probability = 1.0
# Number of simulations:  500
# Pi median Ratio:  0.7588623727094217
# Panmictic Teta = 4*Ne*mu =  2.5e-05
# Mean Pi Autosome:  1.77537306e-05
# ------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# Regression with proba=0 : a = -0.1088471625695629    b = 0.8416929742266402
# Regression without proba=0 : a = -0.05895128824777066    b = 0.8075974601067485
